# %%
import matplotlib.pyplot as plt
import numpy as np

from pyVCT import VCT

# %%
layer = VCT(sizeX=0.3, sizeY=0.3, ncx=6, ncy=6, seed=48, fibers=True, fibers_dist=0.03)
# Out:
# {'GN_CM': 238.22, 'TARGETVOLUME_CM': 214.4, 'INELASTICITY_CM': 69.88, 'DETACH_CM': 16.16, 'GN_FB': 9.62, 'TARGETVOLUME_FB': 148.79999999999998, 'INELASTICITY_FB': 68.05, 'DETACH_FB': 15.2, 'JCMMD': 1.185475, 'JFBMD': 0.7645000000000001, 'JCMCM': 25.0, 'JFBFB': 25.0, 'JFBCM': 25.0, 'UNLEASH_CM': 28.15, 'UNLEASH_FB': 1.44, 'LMAX_CM': 16.924, 'LMAX_FB': 19.488, 'MAX_FOCALS_CM': 10, 'MAX_FOCALS_FB': 22, 'shifts': 0, 'NUCL': 2.0, 'NUCLEI_R': 2.8, 'E_bond': 5.0}
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 layer = VCT(params, sizeX=0.3, sizeY=0.3, ncx=6, ncy=6, seed=48, fibers=True, fibers_dist=0.03)
#
# File ~/pyVCT/pyVCT/vct.py:61, in VCT.__init__(self, energy_params, tissue_type, scenario, sizeX, sizeY, ncx, ncy, part, fibers, seed, path2params, voxsize, fibers_dist)
#      59 print(self.energy_config)
#      60 if fibers:
# ---> 61     self.energy_config = self.energy_config['fiber']
#      62 else:
#      63     self.energy_config = self.energy_config['no_fiber']
#
# KeyError: 'fiber'

# %%
(layer.ctags > 0).sum()
# layer.update_mass_centers(3)
params = layer.energy_config

# %%
layer.draw()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from tqdm import tqdm

for i in tqdm(range(200)):
    layer.step()
layer.draw()
# Out:
#   3%|▎         | 6/200 [00:00<00:25,  7.64it/s]/home/alexey/pyVCT/pyVCT/hamiltonian.py:266: RuntimeWarning: divide by zero encountered in scalar divide
#   coss = np.cos(-np.arctan((xs - CMs[stag][0]) / (ys - CMs[stag][1])))
# 100%|██████████| 200/200 [00:26<00:00,  7.58it/s]
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
(layer.ctags > 0).sum()
# Out:
# 935

# %%
layer.moves
# Out:
# 2793

# %%
layer.types
# Out:
# array([0, 2, 1, 1, 1, 1, 1, 2, 2, 1, 1, 1, 1, 2, 2, 1, 2, 2, 2, 2, 2, 2,
#        2, 1, 2, 2, 1, 1, 2, 2, 1, 1, 2, 1, 1, 1, 2])

# %%
layer.attached
# Out:
# array([0, 9, 8, 8, 8, 8, 8, 9, 9, 8])

# %%
fibers = np.zeros((10, 10))

# %%
fibers[1] = 1

# %%
fibers
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 fibers
#
# NameError: name 'fibers' is not defined
